# %%
using Plots
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1260

# %%
x = 1:10; y = rand(10); # These are the plotting data 
plot(x,y, label="my label")

# %%
using CSV
d = CSV.read("london2018.txt")
# Out:
# 12×6 DataFrames.DataFrame
# │ Row │ Year  │ Month │ Tmax    │ Tmin    │ Rain    │ Sun     │
# │     │ Int64 │ Int64 │ Float64 │ Float64 │ Float64 │ Float64 │
# ├─────┼───────┼───────┼─────────┼─────────┼─────────┼─────────┤
# │ 1   │ 2018  │ 1     │ 9.7     │ 3.8     │ 58.0    │ 46.5    │
# │ 2   │ 2018  │ 2     │ 6.7     │ 0.6     │ 29.0    │ 92.0    │
# │ 3   │ 2018  │ 3     │ 9.8     │ 3.0     │ 81.2    │ 70.3    │
# │ 4   │ 2018  │ 4     │ 15.5    │ 7.9     │ 65.2    │ 113.4   │
# │ 5   │ 2018  │ 5     │ 20.8    │ 9.8     │ 58.4    │ 248.3   │
# │ 6   │ 2018  │ 6     │ 24.2    │ 13.1    │ 0.4     │ 234.5   │
# │ 7   │ 2018  │ 7     │ 28.3    │ 16.4    │ 14.8    │ 272.5   │
# │ 8   │ 2018  │ 8     │ 24.5    │ 14.5    │ 48.2    │ 182.1   │
# │ 9   │ 2018  │ 9     │ 20.9    │ 11.0    │ 29.4    │ 195.0   │
# │ 10  │ 2018  │ 10    │ 16.5    │ 8.5     │ 61.0    │ 137.0   │
# │ 11  │ 2018  │ 11    │ 12.2    │ 5.8     │ 73.8    │ 72.9    │
# │ 12  │ 2018  │ 12    │ 10.7    │ 5.2     │ 60.6    │ 40.3    │

# %%
bar(d.Month,d.Tmax)

# %%
plot(d.Month, d.Tmax)

# %%
plot(d.Month, [d.Tmax, d.Tmin], label=["Tmax","Tmin"])

# %%
using DataFrames, GLM
# Out:
# ┌ Info: Precompiling GLM [38e38edf-8417-5370-95a0-9cbb8c7f171a]
# └ @ Base loading.jl:1260

# %%
data = DataFrame(X=[1,2,3,123,123,213,25,5,5,77,7,7,8], Y=[2,4,7,45,7,8,8,8,8,9,99,9,8])
ols = lm(@formula(Y ~ X), data)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# Y ~ 1 + X
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────────────
#                 Estimate  Std. Error     t value  Pr(>|t|)  Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────────────
# (Intercept)  17.3334        9.52759    1.81929      0.0962  -3.63667   38.3035
# X            -0.00556639    0.119666  -0.0465159    0.9637  -0.268951   0.257818
# ────────────────────────────────────────────────────────────────────────────────

# %%
print(ols)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# Y ~ 1 + X
#
# Coefficients:
# ────────────────────────────────────────────────────────────────────────────
#               Estimate  Std. Error   t value  Pr(>|t|)  Lower 95%  Upper 95%
# ────────────────────────────────────────────────────────────────────────────
# (Intercept)  -0.666667    0.62361   -1.06904    0.4788   -8.59038    7.25704
# X             2.5         0.288675   8.66025    0.0732   -1.16797    6.16797
# ────────────────────────────────────────────────────────────────────────────
